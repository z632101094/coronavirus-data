# %% [markdown]
# # Covid impact on restaurants

# %% [markdown]
# !python --version

# %% [markdown]
# import pandas to preview the dataset

# %%
import pandas as pd

# %%
starbuck = pd.read_csv('StarBucks Covid.csv')

# %%
starbuck
# Out:
#     Column  New York        Borough  income_num_returns(households)  \
# 0       63     10007      MANHATTAN                            3640
# 1      132     10007      MANHATTAN                            3640
# 2      155     10007      MANHATTAN                            3640
# 3      263     10007      MANHATTAN                            3640
# 4      299     10007      MANHATTAN                            3640
# ..     ...       ...            ...                             ...
# 86   10852     10309  STATEN ISLAND                           15270
# 87   11697     10009      MANHATTAN                           32690
# 88   12817     10455          BRONX                           18080
# 89   13176     11355         QUEENS                           52130
# 90   13608     11355         QUEENS                           52130
#
#     avg income per return(x1000s)   income level        DBA            STREET  \
# 0                      693.379945    high income  STARBUCKS          BROADWAY
# 1                      693.379945    high income  STARBUCKS     CHURCH STREET
# 2                      693.379945    high income  STARBUCKS          BROADWAY
# 3                      693.379945    high income  STARBUCKS          BROADWAY
# 4                      693.379945    high income  STARBUCKS          BROADWAY
# ..                            ...            ...        ...               ...
# 86                      90.039424  medium income  STARBUCKS       PAGE AVENUE
# 87                      87.208045  medium income  STARBUCKS          1 AVENUE
# 88                      29.715597     low income  STARBUCKS  EAST  149 STREET
# 89                      29.435373     low income  STARBUCKS       MAIN STREET
# 90                      29.435373     low income  STARBUCKS       MAIN STREET
#
#     GRADE DATE
# 0     3/2/2020
# 1   11/20/2019
# 2   12/16/2019
# 3     1/9/2019
# 4    2/22/2019
# ..         ...
# 86   11/7/2019
# 87    8/5/2019
# 88  11/19/2019
# 89   2/24/2020
# 90   9/24/2019
#
# [91 rows x 9 columns]

# %% [markdown]
# Install pyspark and import pyspark and matplotlib

# %%
pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /Users/gzjchn/opt/anaconda3/lib/python3.8/site-packages (3.1.1)
# Requirement already satisfied: py4j==0.10.9 in /Users/gzjchn/opt/anaconda3/lib/python3.8/site-packages (from pyspark) (0.10.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyspark as spark
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
from pyspark import SparkContext, SQLContext

# %%
sc = SparkContext()
s = SQLContext(sc)

# %%
data = s.read.options(header=True).csv('StarBucks Covid.csv')
data.createOrReplaceTempView("data")

# %% [markdown]
# Print the Schema of the dataset

# %%
data.printSchema()
# Out:
# root
#  |-- Column: string (nullable = true)
#  |-- New York: string (nullable = true)
#  |-- Borough: string (nullable = true)
#  |-- income_num_returns(households): string (nullable = true)
#  |-- avg income per return(x1000s): string (nullable = true)
#  |-- income level: string (nullable = true)
#  |-- DBA: string (nullable = true)
#  |-- STREET: string (nullable = true)
#  |-- GRADE DATE: string (nullable = true)

# %% [markdown]
# Extract columns that I want from the big table

# %%
p = data.select(['income_num_returns(households)','avg income per return(x1000s)','GRADE DATE','STREET'])
p.show()
# Out:
# +------------------------------+-----------------------------+----------+----------------+
# |income_num_returns(households)|avg income per return(x1000s)|GRADE DATE|          STREET|
# +------------------------------+-----------------------------+----------+----------------+
# |                          3640|                  693.3799451|  3/2/2020|        BROADWAY|
# |                          3640|                  693.3799451|11/20/2019|   CHURCH STREET|
# |                          3640|                  693.3799451|12/16/2019|        BROADWAY|
# |                          3640|                  693.3799451|  1/9/2019|        BROADWAY|
# |                          3640|                  693.3799451| 2/22/2019|        BROADWAY|
# |                         15920|                  662.7414573|  1/2/2020|        3 AVENUE|
# |                         15920|                  662.7414573|12/18/2019|        1 AVENUE|
# |                         15920|                  662.7414573| 3/22/2019|        3 AVENUE|
# |                         15920|                  662.7414573| 1/10/2019|        3 AVENUE|
# |                         15920|                  662.7414573| 7/30/2019|        1 AVENUE|
# |                         15920|                  662.7414573|  5/3/2019|LEXINGTON AVENUE|
# |                         23350|                  618.3508779|11/12/2019|EAST   69 STREET|
# |                         23350|                  618.3508779| 11/8/2019|        1 AVENUE|
# |                         23350|                  618.3508779| 1/16/2019|        2 AVENUE|
# |                         23350|                  618.3508779| 6/21/2019|        2 AVENUE|
# |                         20230|                  601.5358873| 2/25/2020|  MADISON AVENUE|
# |                         20230|                  601.5358873|10/15/2019|LEXINGTON AVENUE|
# |                         20230|                  601.5358873|11/18/2019|LEXINGTON AVENUE|
# |                         20230|                  601.5358873|11/13/2019|  MADISON AVENUE|
# |                         20230|                  601.5358873| 12/9/2019| EAST  57 STREET|
# +------------------------------+-----------------------------+----------+----------------+
# only showing top 20 rows

# %% [markdown]
# Compute the count of each store of Starbucks and use the biggest count store to analysis

# %%
data.groupBy("STREET").count().show(100)
# Out:
# +--------------------+-----+
# |              STREET|count|
# +--------------------+-----+
# |    GREENWICH STREET|    1|
# |    EAST  149 STREET|    1|
# |         PAGE AVENUE|    1|
# |            BROADWAY|   12|
# |    EAST   53 STREET|    1|
# |         YORK AVENUE|    1|
# |    EAST   42 STREET|    3|
# |        CANAL STREET|    1|
# |    EAST   80 STREET|    1|
# |    QUEENS BOULEVARD|    3|
# |    WEST   73 STREET|    1|
# |           35 AVENUE|    1|
# |            2 AVENUE|    3|
# |            5 AVENUE|    1|
# |         PARK AVENUE|    1|
# |     COLUMBUS AVENUE|    3|
# |     FLATBUSH AVENUE|    2|
# |    EAST   51 STREET|    1|
# |  CONTINENTAL AVENUE|    2|
# |      MADISON AVENUE|    6|
# |       AUSTIN STREET|    2|
# |            3 AVENUE|    6|
# |    LAFAYETTE STREET|    1|
# |     PARK AVE FRNT 1|    2|
# |AVENUE OF THE AME...|    1|
# |            1 AVENUE|    5|
# |       CHURCH STREET|    1|
# |         MAIN STREET|    3|
# |    WEST   66 STREET|    1|
# |    LEXINGTON AVENUE|   12|
# |    EAST   69 STREET|    1|
# |        WORTH STREET|    2|
# |    EAST   45 STREET|    1|
# |       VARICK STREET|    2|
# |     EAST  57 STREET|    1|
# |       WEST BROADWAY|    4|
# +--------------------+-----+

# %% [markdown]
# Draw the garph for Broadway starbucks

# %%
data.filter(data.STREET == "BROADWAY").show()
p1= data.filter(data.STREET == "BROADWAY").collect()
broadway = []
print(len(p1))
for i in range(len(p1)):
    broadway.append((p1[i][3],p1[i][8]))

bw = np.array(broadway)

sorted(bw, key= lambda x: x[:][0])

income = []
date = []
for i in bw:
    income.append(i[0])
    date.append(i[1])
income = np.array(income)
date = np.array(date)
plt.title('Total income for Broadway starbucks at specific date')
plt.xlabel('dollars')
plt.ylabel('date')
plt.plot(income,date)
# Out:
# +------+--------+---------+------------------------------+-----------------------------+------------+---------+--------+----------+
# |Column|New York|  Borough|income_num_returns(households)|avg income per return(x1000s)|income level|      DBA|  STREET|GRADE DATE|
# +------+--------+---------+------------------------------+-----------------------------+------------+---------+--------+----------+
# |    63|   10007|MANHATTAN|                          3640|                  693.3799451| high income|STARBUCKS|BROADWAY|  3/2/2020|
# |   155|   10007|MANHATTAN|                          3640|                  693.3799451| high income|STARBUCKS|BROADWAY|12/16/2019|
# |   263|   10007|MANHATTAN|                          3640|                  693.3799451| high income|STARBUCKS|BROADWAY|  1/9/2019|
# |   299|   10007|MANHATTAN|                          3640|                  693.3799451| high income|STARBUCKS|BROADWAY| 2/22/2019|
# |  3988|   10013|MANHATTAN|                         15140|                  490.1375165| high income|STARBUCKS|BROADWAY| 4/22/2019|
# |  6935|   10023|MANHATTAN|                         34400|                  401.1237209| high income|STARBUCKS|BROADWAY| 3/11/2020|
# |  7050|   10023|MANHATTAN|                         34400|                  401.1237209| high income|STARBUCKS|BROADWAY|  3/6/2019|
# |  7218|   10023|MANHATTAN|                         34400|                  401.1237209| high income|STARBUCKS|BROADWAY| 7/24/2019|
# |  7301|   10023|MANHATTAN|                         34400|                  401.1237209| high income|STARBUCKS|BROADWAY| 5/17/2019|
# |  7383|   10024|MANHATTAN|                         30540|                  398.9122135| high income|STARBUCKS|BROADWAY|12/27/2019|
# |  7566|   10024|MANHATTAN|                         30540|                  398.9122135| high income|STARBUCKS|BROADWAY| 3/19/2019|
# |  7783|   10024|MANHATTAN|                         30540|                  398.9122135| high income|STARBUCKS|BROADWAY|  8/7/2019|
# +------+--------+---------+------------------------------+-----------------------------+------------+---------+--------+----------+
#
# 12
# <img src="data:image/png;base64,..." width="432">

# %%
plt.close()

# %% [markdown]
# Draw the graph for Lexington ave starbucks

# %%
data.filter(data.STREET == "LEXINGTON AVENUE").show()
p2= data.filter(data.STREET == "LEXINGTON AVENUE").collect()
la = []
print(len(p2))
for i in range(len(p2)):
    la.append((p2[i][3],p2[i][8]))

LA = np.array(la)

sorted(LA, key= lambda x: x[:][0])

income = []
date = []
for i in LA:
    income.append(i[0])
    date.append(i[1])
income = np.array(income)
date = np.array(date)
plt.title('Total income for LEXINGTON AVENUE starbucks at specific date')
plt.xlabel('dollars')
plt.ylabel('date')
plt.plot(income,date)
plt.show()
# Out:
# +------+--------+---------+------------------------------+-----------------------------+------------+---------+----------------+----------+
# |Column|New York|  Borough|income_num_returns(households)|avg income per return(x1000s)|income level|      DBA|          STREET|GRADE DATE|
# +------+--------+---------+------------------------------+-----------------------------+------------+---------+----------------+----------+
# |   924|   10065|MANHATTAN|                         15920|                  662.7414573| high income|STARBUCKS|LEXINGTON AVENUE|  5/3/2019|
# |  1782|   10022|MANHATTAN|                         20230|                  601.5358873| high income|STARBUCKS|LEXINGTON AVENUE|10/15/2019|
# |  1833|   10022|MANHATTAN|                         20230|                  601.5358873| high income|STARBUCKS|LEXINGTON AVENUE|11/18/2019|
# |  2737|   10022|MANHATTAN|                         20230|                  601.5358873| high income|STARBUCKS|LEXINGTON AVENUE| 5/15/2019|
# |  5359|   10017|MANHATTAN|                         12150|                  489.8909465| high income|STARBUCKS|LEXINGTON AVENUE|12/13/2019|
# |  5481|   10017|MANHATTAN|                         12150|                  489.8909465| high income|STARBUCKS|LEXINGTON AVENUE| 3/14/2019|
# |  5513|   10017|MANHATTAN|                         12150|                  489.8909465| high income|STARBUCKS|LEXINGTON AVENUE|  3/7/2019|
# |  6055|   10017|MANHATTAN|                         12150|                  489.8909465| high income|STARBUCKS|LEXINGTON AVENUE| 5/30/2019|
# |  6273|   10028|MANHATTAN|                         25540|                  418.0414644| high income|STARBUCKS|LEXINGTON AVENUE|  3/4/2020|
# |  6328|   10028|MANHATTAN|                         25540|                  418.0414644| high income|STARBUCKS|LEXINGTON AVENUE|10/23/2019|
# |  6449|   10028|MANHATTAN|                         25540|                  418.0414644| high income|STARBUCKS|LEXINGTON AVENUE| 2/27/2019|
# |  6815|   10028|MANHATTAN|                         25540|                  418.0414644| high income|STARBUCKS|LEXINGTON AVENUE| 6/18/2019|
# +------+--------+---------+------------------------------+-----------------------------+------------+---------+----------------+----------+
#
# 12
# <img src="data:," width="0">

# %%
plt.close()

# %%
data1 = s.read.options(header=True).csv('Dunkin-Donats.csv')
data1.createOrReplaceTempView("data1")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ac43aace9faf> in <module>
# ----> 1 data1 = s.read.options(header=True).csv('Dunkin-Donats.csv')
#       2 data1.createOrReplaceTempView("data1")
#
# NameError: name 's' is not defined

# %%
sc.stop()
